# %%
import pandas as pd

# %%
import requests

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 889.7 kB/s eta 0:00:12
#    - -------------------------------------- 0.5/11.0 MB 889.7 kB/s eta 0:00:12
#    -- ------------------------------------- 0.8/11.0 MB 870.9 kB/s eta 0:00:12
#    --- ------------------------------------ 1.0/11.0 MB 854.7 kB/s eta 0:00:12
#    ---- ----------------------------------- 1.3/11.0 MB 883.1 kB/s eta 0:00:11
#    ---- ----------------------------------- 1.3/11.0 MB 883.1 kB/s eta 0:00:11
#    ----- ---------------------------------- 1.6/11.0 MB 896.1 kB/s eta 0:00:11
#    ------ --------------------------------- 1.8/11.0 MB 908.5 kB/s eta 0:00:11
#    ------- -------------------------------- 2.1/11.0 MB 916.9 kB/s eta 0:00:10
# ...

# %%
import xml.etree.ElementTree as ET

# %%
# URL for the API (your provided link)
url = "https://bdl.stat.gov.pl/api/v1/data/by-variable/151889?format=xml&unit-level=2&page-size=100"

# Download XML data
response = requests.get(url)
response.raise_for_status()  # ensure request was successful
xml_data = response.text

# Parse the XML
root = ET.fromstring(xml_data)

# Extract relevant data
records = []
for unit in root.findall(".//unitData"):
    name = unit.find("name").text  # np. MAŁOPOLSKIE
    for year_val in unit.findall(".//yearVal"):
        year = year_val.find("year").text
        val = year_val.find("val").text
        
        if year is None or val is None:
            continue
        
        records.append({
            "Region": name,
            "Year": year,       # jako string
            "Value": float(val)
        })
# Convert to pandas DataFrame
df_il = pd.DataFrame(records)

# Display or save
print("Ilościowe wartość\n",df_il)
df_il.to_csv("bdl_datailosc_2024_.csv", index=False)
# Out:
# Ilościowe wartość
#            Region  Year  Value
# 0    MAŁOPOLSKIE  2009    4.0
# 1    MAŁOPOLSKIE  2010    8.0
# 2    MAŁOPOLSKIE  2011    1.0
# 3    MAŁOPOLSKIE  2012    3.0
# 4    MAŁOPOLSKIE  2013   11.0
# ..           ...   ...    ...
# 251  MAZOWIECKIE  2020  199.0
# 252  MAZOWIECKIE  2021  140.0
# 253  MAZOWIECKIE  2022  108.0
# 254  MAZOWIECKIE  2023   17.0
# 255  MAZOWIECKIE  2024   73.0
#
# [256 rows x 3 columns]

# %% [markdown]
# Obowiązek sprawozdawczy w zakresie danych
# o skupie owoców, grzybów leśnych i zwierząt
# łownych dotyczy osób prawnych i jednostek organi-
# zacyjnych bez osobowości prawnej prowadzących
# w ramach działalności gospodarczej skup produktów
# leśnych, nie dotyczy natomiast osób fizycznych. Da-
# ne o skupie ubocznych produktów leśnych według
# województw podano zgodnie z siedzibą dostawców.
# Dane o skupie owoców leśnych obejmują ga-
# tunki: borówkę czernicę, borówkę brusznicę, żura-
# winę, jeżynę, poziomkę, malinę leśną, inne jagody
# leśne, bez czarny, jarzębinę, różę dziką, głóg, tar-
# ninę, jabłka dzikie i inne owoce leśne.
# Dane o skupie grzybów leśnych obejmują ga-
# tunki: kurki, podgrzybki, borowiki, maślaki i inne
# grzyby leśne.
# Dane o ilości skupionych owoców oraz grzybów
# leśnych dotyczą świeżej masy tych produktów. Dla
# produktów skupionych w stanie suszonym dokonano
# zamiany na świeżą masę stosując umowne wskaź-
# niki przeliczeniowe dla poszczególnych gatunków.
#
#
# Nie wolno ich zbierać w niektórych częściach lasu, gdzie jest stały zakaz wstępu:  na uprawach do 4m wysokości, w drzewostanach nasiennych i powierzchniach doświadczalnych, w ostojach zwierzyny. Nie wolno ich także zbierać na obszarach chronionych: w rezerwatach i parkach narodowych. Rygorystycznie należy przestrzegać zakazu wstępu na tereny wojskowe.

# %%
# URL for the API (your provided link)
url = "https://bdl.stat.gov.pl/api/v1/data/by-variable/151891?format=xml&unit-level=2&page-size=100"

# Download XML data
response = requests.get(url)
response.raise_for_status()  # ensure request was successful
xml_data = response.text

# Parse the XML
root = ET.fromstring(xml_data)

# Extract relevant data
records = []
for unit in root.findall(".//unitData"):
    name = unit.find("name").text  # np. MAŁOPOLSKIE
    for year_val in unit.findall(".//yearVal"):
        year = year_val.find("year").text
        val = year_val.find("val").text
        
        if year is None or val is None:
            continue
        
        records.append({
            "Region": name,
            "Year": year,       # jako string
            "Value": float(val)
        })
# Convert to pandas DataFrame
df_war = pd.DataFrame(records)

# Display or save
print("Cenowo wartość\n",df_war)
df_war.to_csv("bdl_datawartosc_2024_.csv", index=False)
# Out:
# Cenowo wartość
#            Region  Year   Value
# 0    MAŁOPOLSKIE  2009    50.0
# 1    MAŁOPOLSKIE  2010    78.1
# 2    MAŁOPOLSKIE  2011    19.5
# 3    MAŁOPOLSKIE  2012    31.9
# 4    MAŁOPOLSKIE  2013   148.3
# ..           ...   ...     ...
# 251  MAZOWIECKIE  2020  1716.5
# 252  MAZOWIECKIE  2021  2834.0
# 253  MAZOWIECKIE  2022  1697.0
# 254  MAZOWIECKIE  2023   418.0
# 255  MAZOWIECKIE  2024  2095.2
#
# [256 rows x 3 columns]

# %%
# URL for the API (your provided link)
url = "https://bdl.stat.gov.pl/api/v1/data/by-variable/1646060?format=xml&unit-level=2&page-size=100"

# Download XML data
response = requests.get(url)
response.raise_for_status()  # ensure request was successful
xml_data = response.text

# Parse the XML
root = ET.fromstring(xml_data)

# Extract relevant data
records = []
for unit in root.findall(".//unitData"):
    name = unit.find("name").text  # np. MAŁOPOLSKIE
    for year_val in unit.findall(".//yearVal"):
        year = year_val.find("year").text
        val = year_val.find("val").text
        
        if year is None or val is None:
            continue
        
        records.append({
            "Region": name,
            "Year": year,       # jako string
            "Value": float(val)
        })
# Convert to pandas DataFrame
df_war = pd.DataFrame(records)

# Display or save
print("Powierzchnia lasów w łącznej powierzchni gruntów leśnych %\n",df_war)
#df.to_csv("bdl_data_2024_.csv", index=False)
# Out:
# Powierzchnia lasów w łącznej powierzchni gruntów leśnych %
#            Region  Year  Value
# 0    MAŁOPOLSKIE  2010   19.7
# 1    MAŁOPOLSKIE  2011   20.1
# 2    MAŁOPOLSKIE  2012   21.7
# 3    MAŁOPOLSKIE  2013   21.7
# 4    MAŁOPOLSKIE  2014   15.1
# ..           ...   ...    ...
# 235  MAZOWIECKIE  2020   22.0
# 236  MAZOWIECKIE  2021   21.6
# 237  MAZOWIECKIE  2022   23.3
# 238  MAZOWIECKIE  2023   23.7
# 239  MAZOWIECKIE  2024   22.5
#
# [240 rows x 3 columns]

# %%
# URL for the API (your provided link)
url = "https://bdl.stat.gov.pl/api/v1/data/by-variable/194828?format=xml&unit-level=2&page-size=100"

# Download XML data
response = requests.get(url)
response.raise_for_status()  # ensure request was successful
xml_data = response.text

# Parse the XML
root = ET.fromstring(xml_data)

# Extract relevant data
records = []
for unit in root.findall(".//unitData"):
    name = unit.find("name").text  # np. MAŁOPOLSKIE
    for year_val in unit.findall(".//yearVal"):
        year = year_val.find("year").text
        val = year_val.find("val").text
        
        if year is None or val is None:
            continue
        
        records.append({
            "Region": name,
            "Year": year,       # jako string
            "Value": float(val)
        })
# Convert to pandas DataFrame
df_war = pd.DataFrame(records)

# Display or save
print("Lesistość %\n",df_war)
#df.to_csv("bdl_data_2024_.csv", index=False)
# Out:
# Lesistość %
#            Region  Year  Value
# 0    MAŁOPOLSKIE  2009   28.5
# 1    MAŁOPOLSKIE  2010   28.6
# 2    MAŁOPOLSKIE  2011   28.6
# 3    MAŁOPOLSKIE  2012   28.6
# 4    MAŁOPOLSKIE  2013   28.6
# ..           ...   ...    ...
# 251  MAZOWIECKIE  2020   23.4
# 252  MAZOWIECKIE  2021   23.4
# 253  MAZOWIECKIE  2022   23.4
# 254  MAZOWIECKIE  2023   23.4
# 255  MAZOWIECKIE  2024   23.4
#
# [256 rows x 3 columns]

# %%
for n in range(16):
    i =2009 + n
    print("year=",i,"&")
# Out:
# year= 2009 &
# year= 2010 &
# year= 2011 &
# year= 2012 &
# year= 2013 &
# year= 2014 &
# year= 2015 &
# year= 2016 &
# year= 2017 &
# year= 2018 &
# year= 2019 &
# year= 2020 &
# year= 2021 &
# year= 2022 &
# year= 2023 &
# year= 2024 &

# %%
# URL for the API (your provided link)
url = "https://bdl.stat.gov.pl/api/v1/data/by-variable/2039?format=xml&unit-level=2&page-size=100"

# Download XML data
response = requests.get(url)
response.raise_for_status()  # ensure request was successful
xml_data = response.text

# Parse the XML
root = ET.fromstring(xml_data)

# Extract relevant data
records = []
for unit in root.findall(".//unitData"):
    name = unit.find("name").text  # np. MAŁOPOLSKIE
    for year_val in unit.findall(".//yearVal"):
        year = year_val.find("year").text
        val = year_val.find("val").text
        
        if year is None or val is None:
            continue
        
        records.append({
            "Region": name,
            "Year": year,       # jako string
            "Value": float(val)
        })
# Convert to pandas DataFrame
df_war = pd.DataFrame(records)

# Display or save
print("Powierzchnia lasów chronionych [ha]\n",df_war)
df_war.to_csv("bdl_powlaschro_2024_.csv", index=False)
# Out:
# Powierzchnia lasów chronionych [ha]
#            Region  Year     Value
# 0    MAŁOPOLSKIE  1998  12492.10
# 1    MAŁOPOLSKIE  1999  20403.10
# 2    MAŁOPOLSKIE  2000  20494.60
# 3    MAŁOPOLSKIE  2001  20193.60
# 4    MAŁOPOLSKIE  2002  19739.90
# ..           ...   ...       ...
# 427  MAZOWIECKIE  2020  21005.56
# 428  MAZOWIECKIE  2021  21392.47
# 429  MAZOWIECKIE  2022  21139.17
# 430  MAZOWIECKIE  2023  21094.12
# 431  MAZOWIECKIE  2024  21193.36
#
# [432 rows x 3 columns]

# %%
# URL for the API (your provided link)
url = "https://bdl.stat.gov.pl/api/v1/data/by-variable/2037?format=xml&unit-level=2&page-size=100"

# Download XML data
response = requests.get(url)
response.raise_for_status()  # ensure request was successful
xml_data = response.text

# Parse the XML
root = ET.fromstring(xml_data)

# Extract relevant data
records = []
for unit in root.findall(".//unitData"):
    name = unit.find("name").text  # np. MAŁOPOLSKIE
    for year_val in unit.findall(".//yearVal"):
        year = year_val.find("year").text
        val = year_val.find("val").text
        
        if year is None or val is None:
            continue
        
        records.append({
            "Region": name,
            "Year": year,       # jako string
            "Value": float(val)
        })
# Convert to pandas DataFrame
df_war = pd.DataFrame(records)

# Display or save
print("Powierzchnia lasów [ha]\n",df_war)
df_war.to_csv("bdl_powlas_2024_.csv", index=False)
# Out:
# Powierzchnia lasów [ha]
#            Region  Year      Value
# 0    MAŁOPOLSKIE  1998  197996.00
# 1    MAŁOPOLSKIE  1999  198080.70
# 2    MAŁOPOLSKIE  2000  197900.70
# 3    MAŁOPOLSKIE  2001  197963.50
# 4    MAŁOPOLSKIE  2002  197426.20
# ..           ...   ...        ...
# 427  MAZOWIECKIE  2020  377342.47
# 428  MAZOWIECKIE  2021  376442.01
# 429  MAZOWIECKIE  2022  374817.76
# 430  MAZOWIECKIE  2023  373873.05
# 431  MAZOWIECKIE  2024  373392.47
#
# [432 rows x 3 columns]

# %%
# URL for the API (your provided link)
url = "https://bdl.stat.gov.pl/api/v1/data/by-variable/1508?format=xml&unit-level=2&page-size=100"

# Download XML data
response = requests.get(url)
response.raise_for_status()  # ensure request was successful
xml_data = response.text

# Parse the XML
root = ET.fromstring(xml_data)

# Extract relevant data
records = []
for unit in root.findall(".//unitData"):
    name = unit.find("name").text  # np. MAŁOPOLSKIE
    for year_val in unit.findall(".//yearVal"):
        year = year_val.find("year").text
        val = year_val.find("val").text
        
        if year is None or val is None:
            continue
        
        records.append({
            "Region": name,
            "Year": year,       # jako string
            "Value": float(val)
        })
# Convert to pandas DataFrame
df_war = pd.DataFrame(records)

# Display or save
print("Emisja zanieczyszczeń pyłowych[t]\n",df_war)
df_war.to_csv("bdl_data_Zanpyl_.csv", index=False)
# Out:
# Emisja zanieczyszczeń pyłowych[t]
#            Region  Year    Value
# 0    MAŁOPOLSKIE  1996  37151.0
# 1    MAŁOPOLSKIE  1997  29036.0
# 2    MAŁOPOLSKIE  1998  20584.0
# 3    MAŁOPOLSKIE  1999  16588.0
# 4    MAŁOPOLSKIE  2000  16700.0
# ..           ...   ...      ...
# 459  MAZOWIECKIE  2020   2190.0
# 460  MAZOWIECKIE  2021   1992.0
# 461  MAZOWIECKIE  2022   1843.0
# 462  MAZOWIECKIE  2023   1477.0
# 463  MAZOWIECKIE  2024   1257.0
#
# [464 rows x 3 columns]

# %%
# URL for the API (your provided link)
url = "https://bdl.stat.gov.pl/api/v1/data/by-variable/2090?format=xml&unit-level=2&page-size=100"

# Download XML data
response = requests.get(url)
response.raise_for_status()  # ensure request was successful
xml_data = response.text

# Parse the XML
root = ET.fromstring(xml_data)

# Extract relevant data
records = []
for unit in root.findall(".//unitData"):
    name = unit.find("name").text  # np. MAŁOPOLSKIE
    for year_val in unit.findall(".//yearVal"):
        year = year_val.find("year").text
        val = year_val.find("val").text
        
        if year is None or val is None:
            continue
        
        records.append({
            "Region": name,
            "Year": year,       # jako string
            "Value": float(val)
        })
# Convert to pandas DataFrame
df_war = pd.DataFrame(records)

# Display or save
print("Emisja zanieczyszczeń gazowych[t]\n",df_war)
df_war.to_csv("bdl_data_Zangaz_.csv", index=False)
# Out:
# Emisja zanieczyszczeń gazowych[t]
#            Region  Year       Value
# 0    MAŁOPOLSKIE  1998  13714274.0
# 1    MAŁOPOLSKIE  1999  12956071.0
# 2    MAŁOPOLSKIE  2000  13378283.0
# 3    MAŁOPOLSKIE  2001  12689174.0
# 4    MAŁOPOLSKIE  2002  12660893.0
# ..           ...   ...         ...
# 427  MAZOWIECKIE  2020  30623212.0
# 428  MAZOWIECKIE  2021  33445444.0
# 429  MAZOWIECKIE  2022  33337768.0
# 430  MAZOWIECKIE  2023  28355607.0
# 431  MAZOWIECKIE  2024  27335759.0
#
# [432 rows x 3 columns]

# %%
# URL for the API (your provided link)
url = "https://bdl.stat.gov.pl/api/v1/data/by-variable/151909?format=xml&unit-level=2&page-size=100"

# Download XML data
response = requests.get(url)
response.raise_for_status()  # ensure request was successful
xml_data = response.text

# Parse the XML
root = ET.fromstring(xml_data)

# Extract relevant data
records = []
for unit in root.findall(".//unitData"):
    name = unit.find("name").text  # np. MAŁOPOLSKIE
    for year_val in unit.findall(".//yearVal"):
        year = year_val.find("year").text
        val = year_val.find("val").text
        
        if year is None or val is None:
            continue
        
        records.append({
            "Region": name,
            "Year": year,       # jako string
            "Value": float(val)
        })
# Convert to pandas DataFrame
df_war = pd.DataFrame(records)

# Display or save
print("Pozary lasow\n",df_war)
df_war.to_csv("bdl_data_pozar_.csv", index=False)
# Out:
# Pozary lasow
#            Region  Year   Value
# 0    MAŁOPOLSKIE  2009   139.0
# 1    MAŁOPOLSKIE  2010   130.0
# 2    MAŁOPOLSKIE  2011   228.0
# 3    MAŁOPOLSKIE  2012   308.0
# 4    MAŁOPOLSKIE  2013   140.0
# ..           ...   ...     ...
# 251  MAZOWIECKIE  2020  1650.0
# 252  MAZOWIECKIE  2021   689.0
# 253  MAZOWIECKIE  2022  1475.0
# 254  MAZOWIECKIE  2023  1416.0
# 255  MAZOWIECKIE  2024  1683.0
#
# [256 rows x 3 columns]

# %%
# URL for the API (your provided link)
url = "https://bdl.stat.gov.pl/api/v1/data/by-variable/10612?format=xml&unit-level=2&page-size=100"

# Download XML data
response = requests.get(url)
response.raise_for_status()  # ensure request was successful
xml_data = response.text

# Parse the XML
root = ET.fromstring(xml_data)

# Extract relevant data
records = []
for unit in root.findall(".//unitData"):
    name = unit.find("name").text  # np. MAŁOPOLSKIE
    for year_val in unit.findall(".//yearVal"):
        year = year_val.find("year").text
        val = year_val.find("val").text
        
        if year is None or val is None:
            continue
        
        records.append({
            "Region": name,
            "Year": year,       # jako string
            "Value": float(val)
        })
# Convert to pandas DataFrame
df_war = pd.DataFrame(records)

# Display or save
print("Tereny zdewastowane [ha]\n",df_war)
df_war.to_csv("bdl_data_dewastacja_.csv", index=False)
# Out:
# Tereny zdewastowane [ha]
#            Region  Year  Value
# 0    MAŁOPOLSKIE  2003  147.0
# 1    MAŁOPOLSKIE  2004  148.0
# 2    MAŁOPOLSKIE  2005   29.0
# 3    MAŁOPOLSKIE  2006   23.0
# 4    MAŁOPOLSKIE  2007   19.0
# ..           ...   ...    ...
# 347  MAZOWIECKIE  2020  224.0
# 348  MAZOWIECKIE  2021  321.0
# 349  MAZOWIECKIE  2022  288.0
# 350  MAZOWIECKIE  2023  305.0
# 351  MAZOWIECKIE  2024  355.0
#
# [352 rows x 3 columns]

# %%
# URL for the API (your provided link)
url = "https://bdl.stat.gov.pl/api/v1/data/by-variable/101765?format=xml&unit-level=2&page-size=100"

# Download XML data
response = requests.get(url)
response.raise_for_status()  # ensure request was successful
xml_data = response.text

# Parse the XML
root = ET.fromstring(xml_data)

# Extract relevant data
records = []
for unit in root.findall(".//unitData"):
    name = unit.find("name").text  # np. MAŁOPOLSKIE
    for year_val in unit.findall(".//yearVal"):
        year = year_val.find("year").text
        val = year_val.find("val").text
        
        if year is None or val is None:
            continue
        
        records.append({
            "Region": name,
            "Year": year,       # jako string
            "Value": float(val)
        })
# Convert to pandas DataFrame
df_war = pd.DataFrame(records)

# Display or save
print("Tereny zdewastowane [ha]\n",df_war)
df_war.to_csv("bdl_data_dewastacja_.csv", index=False)
# Out:
# Tereny zdewastowane [ha]
#            Region  Year  Value
# 0    MAŁOPOLSKIE  2005   48.3
# 1    MAŁOPOLSKIE  2006   49.0
# 2    MAŁOPOLSKIE  2007   49.9
# 3    MAŁOPOLSKIE  2008   50.0
# 4    MAŁOPOLSKIE  2009   49.5
# ..           ...   ...    ...
# 251  MAZOWIECKIE  2016   56.9
# 252  MAZOWIECKIE  2017   57.3
# 253  MAZOWIECKIE  2018   58.0
# 254  MAZOWIECKIE  2019   59.2
# 255  MAZOWIECKIE  2020   58.0
#
# [256 rows x 3 columns]

# %%
# URL for the API (your provided link)
url = "https://bdl.stat.gov.pl/api/v1/data/by-variable/1632931?format=xml&unit-level=2&page-size=100"

# Download XML data
response = requests.get(url)
response.raise_for_status()  # ensure request was successful
xml_data = response.text

# Parse the XML
root = ET.fromstring(xml_data)

# Extract relevant data
records = []
for unit in root.findall(".//unitData"):
    name = unit.find("name").text  # np. MAŁOPOLSKIE
    for year_val in unit.findall(".//yearVal"):
        year = year_val.find("year").text
        val = year_val.find("val").text
        
        if year is None or val is None:
            continue
        
        records.append({
            "Region": name,
            "Year": year,       # jako string
            "Value": float(val)
        })
# Convert to pandas DataFrame
df_war = pd.DataFrame(records)

# Display or save
print("wskaznik zatrudnienia [%]\n",df_war)
df_war.to_csv("bdl_data_zatrudnienie_.csv", index=False)
# Out:
# wskaznik zatrudnienia [%]
#            Region  Year  Value
# 0    MAŁOPOLSKIE  2010   44.8
# 1    MAŁOPOLSKIE  2011   45.4
# 2    MAŁOPOLSKIE  2012   45.5
# 3    MAŁOPOLSKIE  2013   46.1
# 4    MAŁOPOLSKIE  2014   47.5
# ..           ...   ...    ...
# 235  MAZOWIECKIE  2020   58.6
# 236  MAZOWIECKIE  2021   60.9
# 237  MAZOWIECKIE  2022   61.4
# 238  MAZOWIECKIE  2023   62.0
# 239  MAZOWIECKIE  2024   61.9
#
# [240 rows x 3 columns]
